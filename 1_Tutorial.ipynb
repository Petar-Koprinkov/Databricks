# %% [markdown]
# ### Data Reading CSV

# %%
csv_df = spark.read.table("workspace.default.big_mart_sales")
# csv_df = spark.read.option("header", True).option("inferSchema", True).table("workspace.default.big_mart_sales") -> if we use third party application like Azure/ AWS/ GCP

# %%
# csv_df.show(10) -> The ugly way to display data
display(csv_df.limit(10))

# %% [markdown]
# ### Data Reading JSON

# %%
json_df = spark.read.table("workspace.default.drivers")

# %%
display(json_df.limit(10))

# %%
json_df.count()

# %%
# test
